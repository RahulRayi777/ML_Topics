# ...

# %%
sentences=nltk.sent_tokenize(para)
sentences
# Out:
# ["Hegde's second film release, the Telugu film Oka Laila Kosam (2014), featured her opposite Naga Chaitanya.",
#  'She was praised for her performance in the movie.',
#  'Around the same time, she bagged the nomination for Best Actress at the 62nd Filmfare Awards (South).',
#  "[18] Following a production house and the success of the director Vijay Konda's previous venture, had prompted her to work on the project.",
#  'She undertook Telugu lessons to help her portray the leading female role.',
#  'In her second Telugu film, Hegde impressed many with her memorable performance in "Gopikamma" song from Mukunda (2014).',
#  'It was a romantic-action tale, set in the backdrop of a village, released in late 2014.',
#  "[19][20]\n\n\nPooja Hegde at Mohenjo Daro promotions in 2016\nIn July 2014, Hegde agreed terms to make her Bollywood debut opposite Hrithik Roshan in Ashutosh Gowariker's period film Mohenjo Daro, set against the backdrop of the Indus Valley civilisation.",
# ...

# %%
words=nltk.word_tokenize(para)
words
# Out:
# ['Hegde',
#  "'s",
#  'second',
#  'film',
#  'release',
#  ',',
#  'the',
#  'Telugu',
#  'film',
#  'Oka',
#  'Laila',
#  'Kosam',
#  '(',
#  '2014',
#  ')',
#  ',',
#  'featured',
#  'her',
#  'opposite',
#  'Naga',
#  'Chaitanya',
#  '.',
#  'She',
#  'was',
#  'praised',
#  'for',
#  'her',
#  'performance',
#  'in',
#  'the',
#  'movie',
#  '.',
#  'Around',
#  'the',
#  'same',
#  'time',
#  ',',
#  'she',
#  'bagged',
#  'the',
#  'nomination',
#  'for',
#  'Best',
#  'Actress',
#  'at',
#  'the',
#  '62nd',
#  'Filmfare',
#  'Awards',
#  '(',
#  'South',
#  ')',
#  '.',
#  '[',
#  '18',
#  ']',
#  'Following',
#  'a',
#  'production',
#  'house',
#  'and',
#  'the',
#  'success',
#  'of',
#  'the',
#  'director',
#  'Vijay',
#  'Konda',
#  "'s",
#  'previous',
#  'venture',
#  ',',
#  'had',
#  'prompted',
#  'her',
#  'to',
#  'work',
#  'on',
#  'the',
#  'project',
#  '.',
#  'She',
#  'undertook',
#  'Telugu',
#  'lessons',
#  'to',
#  'help',
#  'her',
#  'portray',
# ...

# %% [markdown]
# # STEMMING

# %%
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()

# %%
len(sentences)
# Out:
# 22

# %%
for i in  range(len(sentences)):
    a=sentences[i]
    print(a)
# Out:
# Hegde's second film release, the Telugu film Oka Laila Kosam (2014), featured her opposite Naga Chaitanya.
# She was praised for her performance in the movie.
# Around the same time, she bagged the nomination for Best Actress at the 62nd Filmfare Awards (South).
# [18] Following a production house and the success of the director Vijay Konda's previous venture, had prompted her to work on the project.
# She undertook Telugu lessons to help her portray the leading female role.
# In her second Telugu film, Hegde impressed many with her memorable performance in "Gopikamma" song from Mukunda (2014).
# It was a romantic-action tale, set in the backdrop of a village, released in late 2014.
# [19][20]
#
#
# Pooja Hegde at Mohenjo Daro promotions in 2016
# In July 2014, Hegde agreed terms to make her Bollywood debut opposite Hrithik Roshan in Ashutosh Gowariker's period film Mohenjo Daro, set against the backdrop of the Indus Valley civilisation.
# ...

# %%
len(words)
# Out:
# 512

# %%
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i]=' '.join(words)

#
by Vamsi Paidipally co-starring by Mahesh Babu. It received mixed reviews on release.[31] Her second Telugu film in the same year was action-thriller the Harish Shankar-directed action thriller film Gaddalakonda Ganesh, a remake of the 2014 Tamil-language film Jigarthanda, featuring Varun Tej and Atharvaa along with her.[32] Hegde returned to Bollywood after a gap of three years with Sajid Nadiadwala\'s comedy film directed by Farhad Samji, featuring her as Rajkumari Mala and Pooja (reincarnated),[33] which went on to gross over ₹280 crore worldwide'''

# %%
paragraph
# Out:
# 'Hegde\'s second film release, the Telugu film Oka Laila Kosam (2014), featured her opposite Naga Chaitanya. She was praised for her performance in the movie. Around the same time, she bagged the nomination for Best Actress at the 62nd Filmfare Awards (South).[18] Following a production house and the success of the director Vijay Konda\'s previous venture, had prompted her to work on the project. She undertook Telugu lessons to help her portray the leading female role. In her second Telugu film, Hegde impressed many with her memorable performance in "Gopikamma" song from Mukunda (2014). It was a romantic-action tale, set in the backdrop of a village, released in late 2014.[19][20]\n\n\nPooja Hegde at Mohenjo Daro promotions in 2016\nIn July 2014, Hegde agreed terms to make her Bollywood debut opposite Hrithik Roshan in Ashutosh Gowariker\'s period film Mohenjo Daro, set against the backdrop of the Indus Valley civilisation. She was selected after Gowariker\'s wife had spotted her in 
# ...

# %%
sent=nltk.sent_tokenize(paragraph)
sent
from nltk.stem import WordNetLemmatizer
lema=WordNetLemmatizer()

# %%
for i in range(len(sent)):
    words=nltk.word_tokenize(sent[i])
    ###in this we tokenise the sentence to word using sent iteration
    words= [lema.lemmatize(word) for word in words  if word not in set(stopwords.words('english'))]
    ###after we lematise and we remove stop words
    sent[i]=' '.join(words)
    ##finally we join

# %%
sent
# Out:
# ["Hegde 's second film release , Telugu film Oka Laila Kosam ( 2014 ) , featured opposite Naga Chaitanya .",
#  'She praised performance movie .',
#  'Around time , bagged nomination Best Actress 62nd Filmfare Awards ( South ) .',
#  "[ 18 ] Following production house success director Vijay Konda 's previous venture , prompted work project .",
#  'She undertook Telugu lesson help portray leading female role .',
#  'In second Telugu film , Hegde impressed many memorable performance `` Gopikamma `` song Mukunda ( 2014 ) .',
#  'It romantic-action tale , set backdrop village , released late 2014 .',
#  "[ 19 ] [ 20 ] Pooja Hegde Mohenjo Daro promotion 2016 In July 2014 , Hegde agreed term make Bollywood debut opposite Hrithik Roshan Ashutosh Gowariker 's period film Mohenjo Daro , set backdrop Indus Valley civilisation .",
#  "She selected Gowariker 's wife spotted advertisement called audition , successfully completed .",
# ...

# %%
sent[i]
# Out:
# "[ 32 ] Hegde returned Bollywood gap three year Sajid Nadiadwala 's comedy film directed Farhad Samji , featuring Rajkumari Mala Pooja ( reincarnated ) , [ 33 ] went gross ₹280 crore worldwide"

# %% [markdown]
# ### it gives meaning full sentences then stemming
